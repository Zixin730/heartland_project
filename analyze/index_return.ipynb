# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Constituents Data
# ## Description

# %%
constituents = pd.read_excel("../crsp_data/constituents.xlsx")
constituents.head()
# Out:
#        Date Ticker  Return RussellMC  RMIDC_WT
# 0  19781229  4165A     NaN         Y    0.1041
# 1  19781229  MNST1     NaN         Y    0.1102
# 2  19781229    ARA     NaN         Y    0.1372
# 3  19781229    ASA     NaN         Y    0.0887
# 4  19781229  2982B     NaN         Y    0.1176

# %%
grouped = constituents.groupby("Date")
describe = grouped.count()[["Ticker", "RussellMC"]].copy()
describe["WT_SUM"] = constituents.dropna(subset=["Ticker"]).groupby("Date").sum().RMIDC_WT
describe
# Out:
#           Ticker  RussellMC     WT_SUM
# Date
# 19781229     755        800  94.804700
# 19790330     761        800  95.503700
# 19790629     762        800  95.484000
# 19790928     761        800  95.547300
# 19791231     764        800  96.372800
# ...          ...        ...        ...
# 20220831     826        826   1.000013
# 20220930     825        825   0.999979
# 20221031     817        817   1.000008
# 20221130     817        817   0.999991
# 20221230     818        818   1.000001
#
# [465 rows x 3 columns]

# %%
constituents["DateTime"] = pd.to_datetime(constituents["Date"].astype(str))
constituents["Year"] = [d.year for d in constituents["DateTime"]]
constituents["Month"] = [d.month for d in constituents["DateTime"]]

# %%
constituents_q = constituents.loc[constituents['Month'].isin([3, 6, 9, 12]), :].copy()
constituents_q.to_excel("../crsp_analysis/constituents_quarterly.xlsx")

# %%
members_ls = constituents_q.Ticker.drop_duplicates()
members_ls.to_csv("../crsp_analysis/constituents_list.csv", index=False)

# %% [markdown]
# ## Returns

# %%
returns = pd.read_csv("../crsp_data/returns.csv")
returns
# Out:
# /Users/zhangzixin/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         TICKER  PERMNO  HdrCUSIP  HdrCUSIP9     CUSIP     CUSIP9  MthCalDt  \
# 0          ACF   10006  00080010  000800102  00080010  000800102  19700130
# 1          ACF   10006  00080010  000800102  00080010  000800102  19700227
# 2          ACF   10006  00080010  000800102  00080010  000800102  19700331
# 3          ACF   10006  00080010  000800102  00080010  000800102  19700430
# 4          ACF   10006  00080010  000800102  00080010  000800102  19700529
# ...        ...     ...       ...        ...       ...        ...       ...
# 1259552   TSLA   93436  88160R10  88160R101  88160R10  88160R101  20220831
# 1259553   TSLA   93436  88160R10  88160R101  88160R10  88160R101  20220930
# 1259554   TSLA   93436  88160R10  88160R101  88160R10  88160R101  20221031
# 1259555   TSLA   93436  88160R10  88160R101  88160R10  88160R101  20221130
# 1259556   TSLA   93436  88160R10  88160R101  88160R10  88160R101  20221230
#
#            MthPrc          MthCap    MthRet   MthRetx  DisFacPr
# 0         46.3750      261,601.38 -0.053571 -0.053571       NaN
# 1         48.1250      271,473.13  0.051272  0.037736       0.0
# 2         49.2500      277,819.25  0.023377  0.023377       NaN
# 3         45.5000      256,665.50 -0.076142 -0.076142       NaN
# 4         38.5000      217,178.50 -0.139744 -0.153846       0.0
# ...           ...             ...       ...       ...       ...
# 1259552  275.6100  863,615,666.70 -0.072489 -0.072489       2.0
# 1259553  265.2500  837,659,500.00 -0.037589 -0.037589       NaN
# 1259554  227.5400  718,514,890.08 -0.142168 -0.142168       NaN
# 1259555  194.7000  614,814,314.40 -0.144326 -0.144326       NaN
# 1259556  123.1800  388,971,891.36 -0.367334 -0.367334       NaN
#
# [1259557 rows x 12 columns]

# %%
grouped = returns.groupby("TICKER")
ls = []
for _, group in grouped:
    # group["QthRet"] = (group["MthRet"] + 1).rolling(3).apply(np.prod, raw=True).shift(-2) - 1
    group["QthRet"] = (group["MthRet"] + 1).rolling(3).apply(np.prod, raw=True) - 1
    ls.append(group)

returns = pd.concat(ls)

# %%
returns["Datetime"] = pd.to_datetime(returns["MthCalDt"].astype(str))
returns["Year"] = [d.year for d in returns["Datetime"]]
returns["Month"] = [d.month for d in returns["Datetime"]]

# %%
returns.columns
# Out:
# Index(['TICKER', 'SecurityNm', 'MthCalDt', 'MthPrcDt', 'MthCap', 'MthPrevCap',
#        'MthRet', 'QthRet', 'Datetime', 'Year', 'Month'],
#       dtype='object')

# %%
returns = returns[['TICKER', 'MthCap', 'QthRet', 'Year', 'Month']].copy()

# %%
from datetime import datetime

# %%
constituents_q["DateQ"] = [datetime.strftime(d, "%m/%d/%Y") for d in constituents_q["DateTime"]]
constituents_q
# Out:
#             Date Ticker    Return RussellMC  RMIDC_WT   DateTime  Year  Month  \
# 0       19781229  4165A       NaN         Y  0.104100 1978-12-29  1978     12
# 1       19781229  MNST1       NaN         Y  0.110200 1978-12-29  1978     12
# 2       19781229    ARA       NaN         Y  0.137200 1978-12-29  1978     12
# 3       19781229    ASA       NaN         Y  0.088700 1978-12-29  1978     12
# 4       19781229  2982B       NaN         Y  0.117600 1978-12-29  1978     12
# ...          ...    ...       ...       ...       ...        ...   ...    ...
# 369689  20221230   ESTC -0.232468         Y  0.000427 2022-12-30  2022     12
# 369690  20221230    LYB  0.156815         Y  0.002285 2022-12-30  2022     12
# 369691  20221230   QGEN -0.637577         Y  0.001211 2022-12-30  2022     12
# 369692  20221230    CPA -0.180029         Y  0.000255 2022-12-30  2022     12
# 369693  20221230    RCL -0.742972         Y  0.001166 2022-12-30  2022     12
#
#              DateQ
# 0       12/29/1978
# 1       12/29/1978
# 2       12/29/1978
# 3       12/29/1978
# 4       12/29/1978
# ...            ...
# 369689  12/30/2022
# 369690  12/30/2022
# 369691  12/30/2022
# 369692  12/30/2022
# 369693  12/30/2022
#
# [141034 rows x 9 columns]

# %%
constituents_q.to_excel("../clean_data/constituents_quarterly.xlsx")

# %%
index_return = constituents_q.merge(returns, left_on=["Ticker", "Year", "Month"], right_on=['TICKER', "Year", "Month"], how="left")
index_return
# Out:
#             Date Ticker    Return RussellMC  RMIDC_WT   DateTime  Year  Month  \
# 0       19781229  4165A       NaN         Y  0.104100 1978-12-29  1978     12
# 1       19781229  MNST1       NaN         Y  0.110200 1978-12-29  1978     12
# 2       19781229    ARA       NaN         Y  0.137200 1978-12-29  1978     12
# 3       19781229    ASA       NaN         Y  0.088700 1978-12-29  1978     12
# 4       19781229  2982B       NaN         Y  0.117600 1978-12-29  1978     12
# ...          ...    ...       ...       ...       ...        ...   ...    ...
# 146056  20221230   ESTC -0.232468         Y  0.000427 2022-12-30  2022     12
# 146057  20221230    LYB  0.156815         Y  0.002285 2022-12-30  2022     12
# 146058  20221230   QGEN -0.637577         Y  0.001211 2022-12-30  2022     12
# 146059  20221230    CPA -0.180029         Y  0.000255 2022-12-30  2022     12
# 146060  20221230    RCL -0.742972         Y  0.001166 2022-12-30  2022     12
#
#        TICKER      MthCap    QthRet
# 0         NaN         NaN       NaN
# 1         NaN         NaN       NaN
# 2         ARA  355,500.00 -0.153256
# 3         ASA  229,200.00 -0.138296
# 4         NaN         NaN       NaN
# ...       ...         ...       ...
# 146056    NaN         NaN       NaN
# 146057    NaN         NaN       NaN
# 146058    NaN         NaN       NaN
# 146059    NaN         NaN       NaN
# 146060    NaN         NaN       NaN
#
# [146061 rows x 11 columns]

# %%
index_return.to_excel("../crsp_analysis/returns_index.xlsx")

# %%
index_return["MthRet_WT"] = index_return.RMIDC_WT * index_return.MthRet

# %%
grouped = index_return.groupby("Date")
describe = grouped.count()[["RussellMC", "Ticker", "MthRet"]].copy()
grouped = index_return.dropna(subset=["MthRet"]).groupby("Date")
describe["WT_SUM"] = grouped.sum().RMIDC_WT
describe["MthMet_equal"] = grouped.mean().MthRet
describe["MthMet_weighted"] = grouped.sum().MthRet_WT/100
describe.to_excel("../crsp_analysis/returns_index_return_monthly.xlsx")

# %% [markdown]
# ## Using Close Price to calculate returns

# %%
ClosePrice = pd.read_csv("../crsp_data/QUOTEMEDIA_PRICES.csv")

# %% [markdown]
# # Index free cash flow on invested capital

# %%
FCFROIC = pd.read_excel("../clean_data/FCFROIC_ADJ_YEARLY_0109.xlsx")
FCFROIC
# Out:
#        Unnamed: 0  Global Company Key  Data Date  Fiscal Year  Fiscal Quarter  \
# 0               0                1004 1971-05-31         1970               4
# 1               1                1004 1972-05-31         1971               4
# 2               2                1004 1973-05-31         1972               4
# 3               3                1004 1974-05-31         1973               4
# 4               4                1004 1975-05-31         1974               4
# ...           ...                 ...        ...          ...             ...
# 61590       61590              328795 2018-12-31         2018               4
# 61591       61591              328795 2019-12-31         2019               4
# 61592       61592              328795 2020-12-31         2020               4
# 61593       61593              328795 2021-12-31         2021               4
# 61594       61594              350681 2021-12-31         2021               4
#
#       Ticker Symbol   FCFROIC  FCFROIC_ADJ  avg_fcfroic_min5  avg_fcfroic_5  \
# 0               AIR       NaN          NaN               NaN            NaN
# 1               AIR       NaN          NaN               NaN            NaN
# 2               AIR       NaN          NaN               NaN            NaN
# 3               AIR       NaN          NaN               NaN            NaN
# 4               AIR       NaN          NaN               NaN            NaN
# ...             ...       ...          ...               ...            ...
# 61590           ACA  0.045054     0.046591               NaN            NaN
# 61591           ACA  0.144107     0.158797               NaN            NaN
# 61592           ACA  0.082630     0.088033               NaN            NaN
# 61593           ACA  0.030491     0.031091               NaN            NaN
# 61594           GET -0.397618    -0.299261               NaN            NaN
#
#        avg_fcfroic_7  avg_fcfroic  avg_fcfroic_cal_min5  avg_fcfroic_cal_5  \
# 0                NaN          NaN                   NaN                NaN
# 1                NaN          NaN                   NaN                NaN
# 2                NaN          NaN                   NaN                NaN
# 3                NaN          NaN                   NaN                NaN
# 4                NaN          NaN                   NaN                NaN
# ...              ...          ...                   ...                ...
# 61590            NaN          NaN                   NaN                NaN
# 61591            NaN          NaN                   NaN                NaN
# 61592            NaN          NaN                   NaN                NaN
# 61593            NaN          NaN                   NaN                NaN
# 61594            NaN          NaN                   NaN                NaN
#
#        avg_fcfroic_cal_7  avg_fcfroic_cal
# 0                    NaN              NaN
# 1                    NaN              NaN
# 2                    NaN              NaN
# 3                    NaN              NaN
# 4                    NaN              NaN
# ...                  ...              ...
# 61590                NaN              NaN
# 61591                NaN              NaN
# 61592                NaN              NaN
# 61593                NaN              NaN
# 61594                NaN              NaN
#
# [61595 rows x 16 columns]

# %%
FCFROIC["next year"] = FCFROIC["Fiscal Year"] + 1

# %%
NAME = "avg_fcfroic"
# 'FCFROIC', 'FCFROIC_ADJ',
#        'avg_fcfroic_min5', 'avg_fcfroic_5', 'avg_fcfroic_7', 'avg_fcfroic',
#        'avg_fcfroic_cal_min5', 'avg_fcfroic_cal_5', 'avg_fcfroic_cal_7',
#        'avg_fcfroic_cal'
FCFROIC_u = FCFROIC[['Data Date', 'Fiscal Year',
       'Fiscal Quarter', 'Ticker Symbol', NAME, 'next year']].copy()

# %%
index_fcfroic = index_return.merge(FCFROIC_u, left_on=["Ticker", "Year"], right_on=["Ticker Symbol", "next year"], how="left")
index_fcfroic
# Out:
#             Date Ticker    Return RussellMC  RMIDC_WT   DateTime  Year  Month  \
# 0       19781229  4165A       NaN         Y  0.104100 1978-12-29  1978     12
# 1       19781229  MNST1       NaN         Y  0.110200 1978-12-29  1978     12
# 2       19781229    ARA       NaN         Y  0.137200 1978-12-29  1978     12
# 3       19781229    ASA       NaN         Y  0.088700 1978-12-29  1978     12
# 4       19781229  2982B       NaN         Y  0.117600 1978-12-29  1978     12
# ...          ...    ...       ...       ...       ...        ...   ...    ...
# 146057  20221230   ESTC -0.232468         Y  0.000427 2022-12-30  2022     12
# 146058  20221230    LYB  0.156815         Y  0.002285 2022-12-30  2022     12
# 146059  20221230   QGEN -0.637577         Y  0.001211 2022-12-30  2022     12
# 146060  20221230    CPA -0.180029         Y  0.000255 2022-12-30  2022     12
# 146061  20221230    RCL -0.742972         Y  0.001166 2022-12-30  2022     12
#
#        TICKER      MthCap    QthRet  Data Date  Fiscal Year  Fiscal Quarter  \
# 0         NaN         NaN       NaN 1977-12-31       1977.0             4.0
# 1         NaN         NaN       NaN        NaT          NaN             NaN
# 2         ARA  355,500.00 -0.153256        NaT          NaN             NaN
# 3         ASA  229,200.00 -0.138296 1977-11-30       1977.0             4.0
# 4         NaN         NaN       NaN        NaT          NaN             NaN
# ...       ...         ...       ...        ...          ...             ...
# 146057    NaN         NaN       NaN 2022-04-30       2021.0             4.0
# 146058    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146059    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146060    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146061    NaN         NaN       NaN 2021-12-31       2021.0             4.0
#
#        Ticker Symbol  avg_fcfroic  next year
# 0              4165A          NaN     1978.0
# 1                NaN          NaN        NaN
# 2                NaN          NaN        NaN
# 3                ASA          NaN     1978.0
# 4                NaN          NaN        NaN
# ...              ...          ...        ...
# 146057          ESTC          NaN     2022.0
# 146058           LYB     0.203045     2022.0
# 146059          QGEN     0.061409     2022.0
# 146060           CPA     0.108201     2022.0
# 146061           RCL    -0.014458     2022.0
#
# [146062 rows x 17 columns]

# %%
# his_mean = index_fcfroic.groupby("DateTime").mean()
# data = his_mean["avg_fcfroic"].dropna()
# data.to_excel("../clean_data/historical_mean_fcfroic.xlsx")

# %% [markdown]
# # Return on Capital

# %%
ecoc = pd.read_excel("../clean_data/ECoC_0109_dropna.xlsx")
ecoc
# Out:
#         Unnamed: 0      beta  name      DATES  GT10 Govt       rf       coe
# 0               60  1.243701     A 1984-03-30   12.47095  0.12471  0.199332
# 1               60  1.737492   AAC 1984-03-30   12.47095  0.12471  0.228959
# 2               60  1.192654   AAL 1984-03-30   12.47095  0.12471  0.196269
# 3               60  1.469890   AAR 1984-03-30   12.47095  0.12471  0.212903
# 4               60  0.999707  ABAN 1984-03-30   12.47095  0.12471  0.184692
# ...            ...       ...   ...        ...        ...      ...       ...
# 756009         247  1.276358  ZBRA 1999-10-29    6.02400  0.06024  0.136822
# 756010         247  1.062015  ZION 1999-10-29    6.02400  0.06024  0.123961
# 756011         247  1.043467   ZLC 1999-10-29    6.02400  0.06024  0.122848
# 756012         247  0.433167   ZNT 1999-10-29    6.02400  0.06024  0.086230
# 756013         247  1.443499   ZQK 1999-10-29    6.02400  0.06024  0.146850
#
# [756014 rows x 7 columns]

# %%
index_fcfroic
# Out:
#             Date Ticker    Return RussellMC  RMIDC_WT   DateTime  Year  Month  \
# 0       19781229  4165A       NaN         Y  0.104100 1978-12-29  1978     12
# 1       19781229  MNST1       NaN         Y  0.110200 1978-12-29  1978     12
# 2       19781229    ARA       NaN         Y  0.137200 1978-12-29  1978     12
# 3       19781229    ASA       NaN         Y  0.088700 1978-12-29  1978     12
# 4       19781229  2982B       NaN         Y  0.117600 1978-12-29  1978     12
# ...          ...    ...       ...       ...       ...        ...   ...    ...
# 146057  20221230   ESTC -0.232468         Y  0.000427 2022-12-30  2022     12
# 146058  20221230    LYB  0.156815         Y  0.002285 2022-12-30  2022     12
# 146059  20221230   QGEN -0.637577         Y  0.001211 2022-12-30  2022     12
# 146060  20221230    CPA -0.180029         Y  0.000255 2022-12-30  2022     12
# 146061  20221230    RCL -0.742972         Y  0.001166 2022-12-30  2022     12
#
#        TICKER      MthCap  ...  FCFROIC_ADJ  avg_fcfroic_min5  avg_fcfroic_5  \
# 0         NaN         NaN  ...          NaN               NaN            NaN
# 1         NaN         NaN  ...          NaN               NaN            NaN
# 2         ARA  355,500.00  ...          NaN               NaN            NaN
# 3         ASA  229,200.00  ...          NaN               NaN            NaN
# 4         NaN         NaN  ...          NaN               NaN            NaN
# ...       ...         ...  ...          ...               ...            ...
# 146057    NaN         NaN  ...     0.021235               NaN            NaN
# 146058    NaN         NaN  ...     0.234606          0.203045       0.159609
# 146059    NaN         NaN  ...     0.111599          0.061409       0.067087
# 146060    NaN         NaN  ...     0.013406          0.108201       0.076716
# 146061    NaN         NaN  ...    -0.168632         -0.014458      -0.042318
#
#        avg_fcfroic_7  avg_fcfroic  avg_fcfroic_cal_min5 avg_fcfroic_cal_5  \
# 0                NaN          NaN                   NaN               NaN
# 1                NaN          NaN                   NaN               NaN
# 2                NaN          NaN                   NaN               NaN
# 3                NaN          NaN                   NaN               NaN
# 4                NaN          NaN                   NaN               NaN
# ...              ...          ...                   ...               ...
# 146057           NaN          NaN                   NaN               NaN
# 146058      0.189975     0.203045              0.233534          0.170503
# 146059      0.066932     0.061409              0.070258          0.077308
# 146060      0.092422     0.108201              0.140770          0.095076
# 146061     -0.027037    -0.014458             -0.018569         -0.049477
#
#         avg_fcfroic_cal_7  avg_fcfroic_cal  next year
# 0                     NaN              NaN     1978.0
# 1                     NaN              NaN        NaN
# 2                     NaN              NaN        NaN
# 3                     NaN              NaN     1978.0
# 4                     NaN              NaN        NaN
# ...                   ...              ...        ...
# 146057                NaN              NaN     2022.0
# 146058           0.209203         0.233534     2022.0
# 146059           0.077002         0.070258     2022.0
# 146060           0.114266         0.140770     2022.0
# 146061          -0.032301        -0.018569     2022.0
#
# [146062 rows x 28 columns]

# %%
ecoc["Datetime"] = pd.to_datetime(ecoc["DATES"])
ecoc["Year"] = [d.year for d in ecoc["Datetime"]]
ecoc["Month"] = [d.month for d in ecoc["Datetime"]]
ecoc
# Out:
#         Unnamed: 0      beta  name      DATES  GT10 Govt       rf       coe  \
# 0               60  1.243701     A 1984-03-30   12.47095  0.12471  0.199332
# 1               60  1.737492   AAC 1984-03-30   12.47095  0.12471  0.228959
# 2               60  1.192654   AAL 1984-03-30   12.47095  0.12471  0.196269
# 3               60  1.469890   AAR 1984-03-30   12.47095  0.12471  0.212903
# 4               60  0.999707  ABAN 1984-03-30   12.47095  0.12471  0.184692
# ...            ...       ...   ...        ...        ...      ...       ...
# 756009         247  1.276358  ZBRA 1999-10-29    6.02400  0.06024  0.136822
# 756010         247  1.062015  ZION 1999-10-29    6.02400  0.06024  0.123961
# 756011         247  1.043467   ZLC 1999-10-29    6.02400  0.06024  0.122848
# 756012         247  0.433167   ZNT 1999-10-29    6.02400  0.06024  0.086230
# 756013         247  1.443499   ZQK 1999-10-29    6.02400  0.06024  0.146850
#
#          Datetime  Year  Month
# 0      1984-03-30  1984      3
# 1      1984-03-30  1984      3
# 2      1984-03-30  1984      3
# 3      1984-03-30  1984      3
# 4      1984-03-30  1984      3
# ...           ...   ...    ...
# 756009 1999-10-29  1999     10
# 756010 1999-10-29  1999     10
# 756011 1999-10-29  1999     10
# 756012 1999-10-29  1999     10
# 756013 1999-10-29  1999     10
#
# [756014 rows x 10 columns]

# %%
ave_ecoc.columns
# Out:
# Index(['Unnamed: 0', 'beta', 'name', 'DATES', 'GT10 Govt', 'rf', 'coe',
#        'Datetime', 'Year', 'Month', '10y_avg'],
#       dtype='object')

# %%
avg_ecoc = ave_ecoc[['name', 'Year', 'Month', '10y_avg']].copy()

# %%
data_all = index_fcfroic.merge(avg_ecoc, left_on=["Ticker", "Year", "Month"], right_on=["name", "Year", "Month"], how="left")
data_all
# Out:
#             Date Ticker    Return RussellMC  RMIDC_WT   DateTime  Year  Month  \
# 0       19781229  4165A       NaN         Y  0.104100 1978-12-29  1978     12
# 1       19781229  MNST1       NaN         Y  0.110200 1978-12-29  1978     12
# 2       19781229    ARA       NaN         Y  0.137200 1978-12-29  1978     12
# 3       19781229    ASA       NaN         Y  0.088700 1978-12-29  1978     12
# 4       19781229  2982B       NaN         Y  0.117600 1978-12-29  1978     12
# ...          ...    ...       ...       ...       ...        ...   ...    ...
# 146057  20221230   ESTC -0.232468         Y  0.000427 2022-12-30  2022     12
# 146058  20221230    LYB  0.156815         Y  0.002285 2022-12-30  2022     12
# 146059  20221230   QGEN -0.637577         Y  0.001211 2022-12-30  2022     12
# 146060  20221230    CPA -0.180029         Y  0.000255 2022-12-30  2022     12
# 146061  20221230    RCL -0.742972         Y  0.001166 2022-12-30  2022     12
#
#        TICKER      MthCap    QthRet  Data Date  Fiscal Year  Fiscal Quarter  \
# 0         NaN         NaN       NaN 1977-12-31       1977.0             4.0
# 1         NaN         NaN       NaN        NaT          NaN             NaN
# 2         ARA  355,500.00 -0.153256        NaT          NaN             NaN
# 3         ASA  229,200.00 -0.138296 1977-11-30       1977.0             4.0
# 4         NaN         NaN       NaN        NaT          NaN             NaN
# ...       ...         ...       ...        ...          ...             ...
# 146057    NaN         NaN       NaN 2022-04-30       2021.0             4.0
# 146058    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146059    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146060    NaN         NaN       NaN 2021-12-31       2021.0             4.0
# 146061    NaN         NaN       NaN 2021-12-31       2021.0             4.0
#
#        Ticker Symbol  avg_fcfroic  next year name  10y_avg
# 0              4165A          NaN     1978.0  NaN      NaN
# 1                NaN          NaN        NaN  NaN      NaN
# 2                NaN          NaN        NaN  NaN      NaN
# 3                ASA          NaN     1978.0  NaN      NaN
# 4                NaN          NaN        NaN  NaN      NaN
# ...              ...          ...        ...  ...      ...
# 146057          ESTC          NaN     2022.0  NaN      NaN
# 146058           LYB     0.203045     2022.0  NaN      NaN
# 146059          QGEN     0.061409     2022.0  NaN      NaN
# 146060           CPA     0.108201     2022.0  NaN      NaN
# 146061           RCL    -0.014458     2022.0  NaN      NaN
#
# [146062 rows x 19 columns]

# %%
quality = data_all.copy()

quality["ind"] = np.nan
quality.loc[(quality[NAME] >=
            quality["10y_avg"]), "ind"] = 1
quality.loc[(quality[NAME] <
            quality["10y_avg"]), "ind"] = 0

# %%
quality.to_excel("../crsp_analysis/quality_0210_{NAME}.xlsx".format(NAME=NAME))

# %%
quality.columns
# Out:
# Index(['Date', 'Ticker', 'Return', 'RussellMC', 'RMIDC_WT', 'DateTime', 'Year',
#        'Month', 'TICKER', 'MthCap', 'QthRet', 'Data Date', 'Fiscal Year',
#        'Fiscal Quarter', 'Ticker Symbol', 'avg_fcfroic_min5', 'next year',
#        'name', '10y_avg', 'ind'],
#       dtype='object')

# %%
high_q = quality[quality['ind'] == 1].copy()
high_ret = high_q.groupby("Date").mean().QthRet
low_q = quality[quality['ind'] == 0].copy()
low_ret = low_q.groupby("Date").mean().QthRet

# %%
total_ret = quality.groupby("Date").mean().QthRet

# %%
ret_all = pd.DataFrame()
ret_all["high quality"] = high_ret
ret_all["low quality"] = low_ret
ret_all["total"] = total_ret

# %%
cumulative = (ret_all + 1).cumprod() - 1
ret_all[["high cum", "low cum", "total cum"]] = cumulative

# %%
ret_all.to_excel('../crsp_analysis/ret_high_low_all.xlsx')

# %%
grouped = quality.groupby("Date")
grouped.mean().dropna(how="all").to_excel("../crsp_analysis/quality_rate.xlsx")

# %%
grouped.count().to_excel("../crsp_analysis/quality_num.xlsx")

# %%
high_quality = quality[quality['ind'] == 1].copy()
grouped = high_quality.groupby("Date")
grouped.count().to_excel("../crsp_analysis/quality_hq_num.xlsx")
